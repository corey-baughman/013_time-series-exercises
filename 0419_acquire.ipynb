# %%
import numpy as np
import pandas as pd
import requests
import os

import acquire as a

# %%
# https://aphorisms.glitch.me returns a random quotation
response = requests.get('http://aphorisms.glitch.me/')

# %%
response
# Out:
# <Response [200]>

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"quote":"Find out who you are and do it on purpose","author":"Dolly Parton"}'

# %%
url = 'https://swapi.dev/api/people/5'
response = requests.get(url)
print(response.text)
# Out:
# {"name":"Leia Organa","height":"150","mass":"49","hair_color":"brown","skin_color":"light","eye_color":"brown","birth_year":"19BBY","gender":"female","homeworld":"https://swapi.dev/api/planets/2/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/30/"],"starships":[],"created":"2014-12-10T15:20:09.791000Z","edited":"2014-12-20T21:17:50.315000Z","url":"https://swapi.dev/api/people/5/"}

# %%
data = response.json()
print(type(data))
data
# Out:
# <class 'dict'>
# {'name': 'Leia Organa',
#  'height': '150',
#  'mass': '49',
#  'hair_color': 'brown',
#  'skin_color': 'light',
#  'eye_color': 'brown',
#  'birth_year': '19BBY',
#  'gender': 'female',
#  'homeworld': 'https://swapi.dev/api/planets/2/',
#  'films': ['https://swapi.dev/api/films/1/',
#   'https://swapi.dev/api/films/2/',
#   'https://swapi.dev/api/films/3/',
#   'https://swapi.dev/api/films/6/'],
#  'species': [],
#  'vehicles': ['https://swapi.dev/api/vehicles/30/'],
#  'starships': [],
#  'created': '2014-12-10T15:20:09.791000Z',
#  'edited': '2014-12-20T21:17:50.315000Z',
#  'url': 'https://swapi.dev/api/people/5/'}

# %%
root_url = 'https://swapi.dev/api/'
response = requests.get(root_url)
print(response)
response.json()
# Out:
# <Response [200]>
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
response = requests.get('https://swapi.dev/api/people/')

data = response.json()
data.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
number_of_people = data['count']
next_page = data['next']
previous_page = data['previous']

print(f'number_of_people: {number_of_people}')
print(f'next_page: {next_page}')
print(f'previous_page: {previous_page}')
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=2
# previous_page: None

# %%
data['results'][:2]
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'https://swapi.dev/api/planets/1/',
#   'films': ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['https://swapi.dev/api/vehicles/14/',
#    'https://swapi.dev/api/vehicles/30/'],
#   'starships': ['https://swapi.dev/api/starships/12/',
#    'https://swapi.dev/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'https://swapi.dev/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
#   'gender': 'n/a',
#   'homeworld': 'https://swapi.dev/api/planets/1/',
#   'films': ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   'species': ['https://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:10:51.357000Z',
#   'edited': '2014-12-20T21:17:50.309000Z',
#   'url': 'https://swapi.dev/api/people/2/'}]

# %%
import math

# %%
number_of_results = len(data['results'])
max_page = math.ceil(number_of_people / number_of_results)

print(f'number_of_results: {number_of_results}')
print(f'max_page {max_page}')
# Out:
# number_of_results: 10
# max_page 9

# %%
df = pd.DataFrame(data['results'])
df.head()
# Out:
#                name height  mass hair_color skin_color eye_color birth_year  \
# 0         Boba Fett    183  78.2      black       fair     brown    31.5BBY
# 1             IG-88    200   140       none      metal       red      15BBY
# 2             Bossk    190   113       none      green       red      53BBY
# 3  Lando Calrissian    177    79      black       dark     brown      31BBY
# 4             Lobot    175    79       none      light      blue      37BBY
#
#   gender                          homeworld  \
# 0   male  https://swapi.dev/api/planets/10/
# 1   none  https://swapi.dev/api/planets/28/
# 2   male  https://swapi.dev/api/planets/29/
# 3   male  https://swapi.dev/api/planets/30/
# 4   male   https://swapi.dev/api/planets/6/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/2/, https://swapi...
# 1                   [https://swapi.dev/api/films/2/]
# 2                   [https://swapi.dev/api/films/2/]
# 3  [https://swapi.dev/api/films/2/, https://swapi...
# 4                   [https://swapi.dev/api/films/2/]
#
#                               species vehicles  \
# 0                                  []       []
# 1  [https://swapi.dev/api/species/2/]       []
# 2  [https://swapi.dev/api/species/7/]       []
# 3                                  []       []
# 4                                  []       []
#
#                                starships                      created  \
# 0  [https://swapi.dev/api/starships/21/]  2014-12-15T12:49:32.457000Z
# 1                                     []  2014-12-15T12:51:10.076000Z
# 2                                     []  2014-12-15T12:53:49.297000Z
# 3  [https://swapi.dev/api/starships/10/]  2014-12-15T12:56:32.683000Z
# 4                                     []  2014-12-15T13:01:57.178000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.349000Z  https://swapi.dev/api/people/22/
# 1  2014-12-20T21:17:50.351000Z  https://swapi.dev/api/people/23/
# 2  2014-12-20T21:17:50.355000Z  https://swapi.dev/api/people/24/
# 3  2014-12-20T21:17:50.357000Z  https://swapi.dev/api/people/25/
# 4  2014-12-20T21:17:50.359000Z  https://swapi.dev/api/people/26/

# %%
df.shape
# Out:
# (10, 16)

# %%
response = requests.get(data['next'])
data = response.json()

number_of_people = data['count']
next_page = data['next']
previous_page = data['previous']
number_of_results = len(data['results'])
max_page = math.ceil(number_of_people / number_of_results)

print(f'number_of_people: {number_of_people}')
print(f'next_page: {next_page}')
print(f'previous_page: {previous_page}')
print(f'number_of_results: {number_of_results}')
print(f'max_page: {max_page}')

df = pd.concat([df, pd.DataFrame(data['results'])]).reset_index()
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=3
# previous_page: https://swapi.dev/api/people/?page=1
# number_of_results: 10
# max_page: 9

# %%
response = requests.get(data['next'])
data = response.json()

number_of_people = data['count']
next_page = data['next']
previous_page = data['previous']
number_of_results = len(data['results'])
max_page = math.ceil(number_of_people / number_of_results)

print(f'number_of_people: {number_of_people}')
print(f'next_page: {next_page}')
print(f'previous_page: {previous_page}')
print(f'number_of_results: {number_of_results}')
print(f'max_page: {max_page}')

df = pd.concat([df, pd.DataFrame(data['results'])]).reset_index()
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=4
# previous_page: https://swapi.dev/api/people/?page=2
# number_of_results: 10
# max_page: 9

# %%
df.shape
# Out:
# (30, 18)

# %% [markdown]
# #### 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
a.see_swapi_categories()
# Out:
# dict_keys(['people', 'planets', 'films', 'species', 'vehicles', 'starships'])

# %%
people = a.get_swapi_category_data('people')
people.head()
# Out:
# Local file found!
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        NaN         gold    yellow     112BBY
# 2           R2-D2     96   32        NaN  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     NaN  https://swapi.dev/api/planets/1/
# 2     NaN  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2  ['https://swapi.dev/api/films/1/', 'https://sw...
# 3  ['https://swapi.dev/api/films/1/', 'https://sw...
# 4  ['https://swapi.dev/api/films/1/', 'https://sw...
#
#                                 species  \
# 0                                    []
# 1  ['https://swapi.dev/api/species/2/']
# 2  ['https://swapi.dev/api/species/2/']
# 3                                    []
# 4                                    []
#
#                                             vehicles  \
# 0  ['https://swapi.dev/api/vehicles/14/', 'https:...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4             ['https://swapi.dev/api/vehicles/30/']
#
#                                            starships  \
# 0  ['https://swapi.dev/api/starships/12/', 'https...
# 1                                                 []
# 2                                                 []
# 3            ['https://swapi.dev/api/starships/13/']
# 4                                                 []
#
#                        created                       edited  \
# 0  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
#
#                                url
# 0  https://swapi.dev/api/people/1/
# 1  https://swapi.dev/api/people/2/
# 2  https://swapi.dev/api/people/3/
# 3  https://swapi.dev/api/people/4/
# 4  https://swapi.dev/api/people/5/

# %%
people.shape
# Out:
# (82, 16)

# %% [markdown]
# #### 2. Do the same thing, but for planets.

# %%
planets = a.get_swapi_category_data('planets')
# Out:
# Local file found!

# %%
planets.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           NaN                      swamp, jungles             8     unknown
#
#                                            residents  \
# 0  ['https://swapi.dev/api/people/1/', 'https://s...
# 1  ['https://swapi.dev/api/people/5/', 'https://s...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2                 ['https://swapi.dev/api/films/1/']
# 3                 ['https://swapi.dev/api/films/2/']
# 4  ['https://swapi.dev/api/films/2/', 'https://sw...
#
#                        created                       edited  \
# 0  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 1  2014-12-10T11:35:48.479000Z  2014-12-20T20:58:18.420000Z
# 2  2014-12-10T11:37:19.144000Z  2014-12-20T20:58:18.421000Z
# 3  2014-12-10T11:39:13.934000Z  2014-12-20T20:58:18.423000Z
# 4  2014-12-10T11:42:22.590000Z  2014-12-20T20:58:18.425000Z
#
#                                 url
# 0  https://swapi.dev/api/planets/1/
# 1  https://swapi.dev/api/planets/2/
# 2  https://swapi.dev/api/planets/3/
# 3  https://swapi.dev/api/planets/4/
# 4  https://swapi.dev/api/planets/5/

# %% [markdown]
# #### 3. Extract the data for starships.

# %%
starships = a.get_swapi_category_data('starships')
# Out:
# Local file found!

# %%
starships.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060        NaN       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                    NaN  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                   starship_class  \
# 0               2.0   60                         corvette
# 1               2.0   60                   Star Destroyer
# 2               1.0   70                    landing craft
# 3               4.0   10  Deep Space Mobile Battlestation
# 4               0.5   75                  Light freighter
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['https://swapi.dev/api/people/13/', 'https://...
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2                 ['https://swapi.dev/api/films/1/']
# 3                 ['https://swapi.dev/api/films/1/']
# 4  ['https://swapi.dev/api/films/1/', 'https://sw...
#
#                        created                       edited  \
# 0  2014-12-10T14:20:33.369000Z  2014-12-20T21:23:49.867000Z
# 1  2014-12-10T15:08:19.848000Z  2014-12-20T21:23:49.870000Z
# 2  2014-12-10T15:48:00.586000Z  2014-12-20T21:23:49.873000Z
# 3  2014-12-10T16:36:50.509000Z  2014-12-20T21:26:24.783000Z
# 4  2014-12-10T16:59:45.094000Z  2014-12-20T21:23:49.880000Z
#
#                                    url
# 0   https://swapi.dev/api/starships/2/
# 1   https://swapi.dev/api/starships/3/
# 2   https://swapi.dev/api/starships/5/
# 3   https://swapi.dev/api/starships/9/
# 4  https://swapi.dev/api/starships/10/

# %% [markdown]
# #### 4. Save the data in your files to local csv files so that it will be faster to access in the future.
#
# See acquire.py 'get_swapi_category_data()''

# %% [markdown]
# #### 5. Combine the data from your three separate dataframes into one large dataframe.

# %%
star_wars = pd.concat([people, planets, starships])
star_wars.head().T
# Out:
#                                                                         0  \
# name                                                       Luke Skywalker
# height                                                                172
# mass                                                                   77
# hair_color                                                          blond
# skin_color                                                           fair
# eye_color                                                            blue
# birth_year                                                          19BBY
# gender                                                               male
# homeworld                                https://swapi.dev/api/planets/1/
# films                   ['https://swapi.dev/api/films/1/', 'https://sw...
# species                                                                []
# vehicles                ['https://swapi.dev/api/vehicles/14/', 'https:...
# starships               ['https://swapi.dev/api/starships/12/', 'https...
# created                                       2014-12-09T13:50:51.644000Z
# edited                                        2014-12-20T21:17:56.891000Z
# url                                       https://swapi.dev/api/people/1/
# rotation_period                                                       NaN
# orbital_period                                                        NaN
# diameter                                                              NaN
# climate                                                               NaN
# gravity                                                               NaN
# terrain                                                               NaN
# surface_water                                                         NaN
# population                                                            NaN
# residents                                                             NaN
# model                                                                 NaN
# manufacturer                                                          NaN
# cost_in_credits                                                       NaN
# length                                                                NaN
# max_atmosphering_speed                                                NaN
# crew                                                                  NaN
# passengers                                                            NaN
# cargo_capacity                                                        NaN
# consumables                                                           NaN
# hyperdrive_rating                                                     NaN
# MGLT                                                                  NaN
# starship_class                                                        NaN
# pilots                                                                NaN
#
#                                                                         1  \
# name                                                                C-3PO
# height                                                                167
# mass                                                                   75
# hair_color                                                            NaN
# skin_color                                                           gold
# eye_color                                                          yellow
# birth_year                                                         112BBY
# gender                                                                NaN
# homeworld                                https://swapi.dev/api/planets/1/
# films                   ['https://swapi.dev/api/films/1/', 'https://sw...
# species                              ['https://swapi.dev/api/species/2/']
# vehicles                                                               []
# starships                                                              []
# created                                       2014-12-10T15:10:51.357000Z
# edited                                        2014-12-20T21:17:50.309000Z
# url                                       https://swapi.dev/api/people/2/
# rotation_period                                                       NaN
# orbital_period                                                        NaN
# diameter                                                              NaN
# climate                                                               NaN
# gravity                                                               NaN
# terrain                                                               NaN
# surface_water                                                         NaN
# population                                                            NaN
# residents                                                             NaN
# model                                                                 NaN
# manufacturer                                                          NaN
# cost_in_credits                                                       NaN
# length                                                                NaN
# max_atmosphering_speed                                                NaN
# crew                                                                  NaN
# passengers                                                            NaN
# cargo_capacity                                                        NaN
# consumables                                                           NaN
# hyperdrive_rating                                                     NaN
# MGLT                                                                  NaN
# starship_class                                                        NaN
# pilots                                                                NaN
#
#                                                                         2  \
# name                                                                R2-D2
# height                                                                 96
# mass                                                                   32
# hair_color                                                            NaN
# skin_color                                                    white, blue
# eye_color                                                             red
# birth_year                                                          33BBY
# gender                                                                NaN
# homeworld                                https://swapi.dev/api/planets/8/
# films                   ['https://swapi.dev/api/films/1/', 'https://sw...
# species                              ['https://swapi.dev/api/species/2/']
# vehicles                                                               []
# starships                                                              []
# created                                       2014-12-10T15:11:50.376000Z
# edited                                        2014-12-20T21:17:50.311000Z
# url                                       https://swapi.dev/api/people/3/
# rotation_period                                                       NaN
# orbital_period                                                        NaN
# diameter                                                              NaN
# climate                                                               NaN
# gravity                                                               NaN
# terrain                                                               NaN
# surface_water                                                         NaN
# population                                                            NaN
# residents                                                             NaN
# model                                                                 NaN
# manufacturer                                                          NaN
# cost_in_credits                                                       NaN
# length                                                                NaN
# max_atmosphering_speed                                                NaN
# crew                                                                  NaN
# passengers                                                            NaN
# cargo_capacity                                                        NaN
# consumables                                                           NaN
# hyperdrive_rating                                                     NaN
# MGLT                                                                  NaN
# starship_class                                                        NaN
# pilots                                                                NaN
#
#                                                                         3  \
# name                                                          Darth Vader
# height                                                                202
# mass                                                                  136
# hair_color                                                           none
# skin_color                                                          white
# eye_color                                                          yellow
# birth_year                                                        41.9BBY
# gender                                                               male
# homeworld                                https://swapi.dev/api/planets/1/
# films                   ['https://swapi.dev/api/films/1/', 'https://sw...
# species                                                                []
# vehicles                                                               []
# starships                         ['https://swapi.dev/api/starships/13/']
# created                                       2014-12-10T15:18:20.704000Z
# edited                                        2014-12-20T21:17:50.313000Z
# url                                       https://swapi.dev/api/people/4/
# rotation_period                                                       NaN
# orbital_period                                                        NaN
# diameter                                                              NaN
# climate                                                               NaN
# gravity                                                               NaN
# terrain                                                               NaN
# surface_water                                                         NaN
# population                                                            NaN
# residents                                                             NaN
# model                                                                 NaN
# manufacturer                                                          NaN
# cost_in_credits                                                       NaN
# length                                                                NaN
# max_atmosphering_speed                                                NaN
# crew                                                                  NaN
# passengers                                                            NaN
# cargo_capacity                                                        NaN
# consumables                                                           NaN
# hyperdrive_rating                                                     NaN
# MGLT                                                                  NaN
# starship_class                                                        NaN
# pilots                                                                NaN
#
#                                                                         4
# name                                                          Leia Organa
# height                                                                150
# mass                                                                   49
# hair_color                                                          brown
# skin_color                                                          light
# eye_color                                                           brown
# birth_year                                                          19BBY
# gender                                                             female
# homeworld                                https://swapi.dev/api/planets/2/
# films                   ['https://swapi.dev/api/films/1/', 'https://sw...
# species                                                                []
# vehicles                           ['https://swapi.dev/api/vehicles/30/']
# starships                                                              []
# created                                       2014-12-10T15:20:09.791000Z
# edited                                        2014-12-20T21:17:50.315000Z
# url                                       https://swapi.dev/api/people/5/
# rotation_period                                                       NaN
# orbital_period                                                        NaN
# diameter                                                              NaN
# climate                                                               NaN
# gravity                                                               NaN
# terrain                                                               NaN
# surface_water                                                         NaN
# population                                                            NaN
# residents                                                             NaN
# model                                                                 NaN
# manufacturer                                                          NaN
# cost_in_credits                                                       NaN
# length                                                                NaN
# max_atmosphering_speed                                                NaN
# crew                                                                  NaN
# passengers                                                            NaN
# cargo_capacity                                                        NaN
# consumables                                                           NaN
# hyperdrive_rating                                                     NaN
# MGLT                                                                  NaN
# starship_class                                                        NaN
# pilots                                                                NaN

# %% [markdown]
# #### 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
url = 'https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv'
df = pd.read_csv(url)
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
a.get_energy_data()
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# #### 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.
#
# see acquire.py file in this repo.
